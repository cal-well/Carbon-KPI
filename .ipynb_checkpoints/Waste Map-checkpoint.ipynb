# %% [markdown]
# # Use kepler gl + Housing data to create basic visualisation

# %%
from keplergl import KeplerGl
import pandas as pd
import geopandas as gpd

# %%
# read Sample data 
my_data= pd.read_csv('Data/Waste_Flow.csv')

# %% [markdown]
# Configure the map:
# 1) upload csv data file to https://kepler.gl/demo
#
# 2) Configure map settings on the web app
#
# 3) Export map
#
# 4) Copy map JSON settings
#
# 5) Paste below
#
# 6) Capitalise true & false. Change null to None
#
# 7) reformat to readable code
#
# 6) Rename 'dataId' to my_data

# %%
config = {
  "version": "v1",
  "config": {
    "visState": {
      "filters": [],
      "layers": [
        {
          "id": "8167oue",
          "type": "point",
          "config": {
            "dataId": "my_data",
            "label": "target",
            "color": [
235, 188, 127            ],
            "highlightColor": [
              252,
              242,
              26,
              255
            ],
            "columns": {
              "lat": "Target Latitude",
              "lng": "Target Longitude",
              "altitude": None
            },
            "isVisible": True,
            "visConfig": {
              "radius": 20,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "batfjrp",
          "type": "point",
          "config": {
            "dataId": "my_data",
            "label": "source",
            "color": [
              50,
              26,
              151
            ],
            "highlightColor": [
              252,
              242,
              26,
              255
            ],
            "columns": {
              "lat": "Source Latitude",
              "lng": "Source Longitude",
              "altitude": None
            },
            "isVisible": True,
            "visConfig": {
              "radius": 25,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "55la7j",
          "type": "arc",
          "config": {
            "dataId": "my_data",
            "label": "target -> source arc",
            "color": [
              146,
              38,
              198
            ],
            "highlightColor": [
              252,
              242,
              26,
              255
            ],
            "columns": {
              "lat0": "Target Latitude",
              "lng0": "Target Longitude",
              "lat1": "Source Latitude",
              "lng1": "Source Longitude"
            },
            "isVisible": True,
            "visConfig": {
              "opacity": 0.8,
              "thickness": 2,
              "colorRange": {
                "name": "Custom Palette",
                "type": "custom",
                "category": "Custom",
                "colors": [
                  "#C50F3C",
                  "#E3611C",
                  "#F1920E",
                  "#FFD200",
                  "#C3D600",
                  "#76BD22",
                      "#00C4B4",
                  "#5FB4E5",
                    "#7f87cf",
                  "#000F9F"
                ]
              },
              "sizeRange": [
                1,
                10
              ],
              "targetColor": None
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": {
              "name": "Material ",
              "type": "string"
            },
            "colorScale": "ordinal",
            "sizeField": {
              "name": "Tonnage",
              "type": "real"
            },
            "sizeScale": "linear"
          }
        },
        {
          "id": "z00tibj",
          "type": "line",
          "config": {
            "dataId": "my_data",
            "label": "target -> source line",
            "color": [
              248,
              149,
              112
            ],
            "highlightColor": [
              252,
              242,
              26,
              255
            ],
            "columns": {
              "lat0": "Target Latitude",
              "lng0": "Target Longitude",
              "alt0": None,
              "lat1": "Source Latitude",
              "lng1": "Source Longitude",
              "alt1": None
            },
            "isVisible": False,
            "visConfig": {
              "opacity": 0.8,
              "thickness": 2,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "sizeRange": [
                0,
                10
              ],
              "targetColor": None,
              "elevationScale": 1
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        }
      ],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "my_data": [
              {
                "name": "Material ",
                "format": None
              },
              {
                "name": "Location",
                "format": None
              },
              {
                "name": "Tonnage",
                "format": None
              }
            ]
          },
          "compareMode": False,
          "compareType": "absolute",
          "enabled": True
        },
        "brush": {
          "size": 0.5,
          "enabled": False
        },
        "geocoder": {
          "enabled": False
        },
        "coordinate": {
          "enabled": False
        }
      },
      "layerBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": None,
        "speed": 1
      }
    },
    "mapState": {
      "bearing": 80,
      "dragRotate": True,
      "latitude": 53.55387072779484,
      "longitude": -5.14115831693209248,
      "pitch": 59.403476390569764,
      "zoom": 6,
      "isSplit": False
    },
    "mapStyle": {
      "styleType": "muted",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": True,
        "road": True,
        "border": False,
        "building": True,
        "water": True,
        "land": True,
        "3d building": False
      },
      "threeDBuildingColor": [
        224.4071295378559,
        224.4071295378559,
        224.4071295378559
      ],
      "mapStyles": {}
    }
  }
}

# %%
# Create a Kepler.gl map with above configuration
map_1 = KeplerGl(height=500,config =config)
# Add data to the map
map_1.add_data(data=my_data, name='my_data')
#save to html
map_1.save_to_html(file_name='Blocks/Waste Map.html')
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Map saved to Blocks/Waste Map.html!
